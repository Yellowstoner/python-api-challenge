# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Set URLs
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Variables and Lists
city_id = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# counters
record = 0
record_set = 1

# %%
# Data Retrieval
print("Beginning Data Retrieval ")
print("-----------------------------")

for i, city in enumerate(cities): 

    if (i % 50 == 0 and i >= 50):
        record_set += 1
        record = 0
        
    record += 1
        
    city_url = base_url + "&q=" + city

    try:
        response = requests.get(f"{city_url}").json()
        city_id.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        
        city_record = response["name"]
        print(f'Processing Record {record} of Set {record_set} | {response["name"]}')
        
    except:
        print(f"City not found. Skipping...")
        
    continue
              
print(f"-----------------------------")
print(f"Data Retrieval Complete")
print(f"-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | Beni Mazar
# Processing Record 2 of Set 1 | Hilo
# Processing Record 3 of Set 1 | George Town
# Processing Record 4 of Set 1 | Avarua
# Processing Record 5 of Set 1 | Zonguldak
# Processing Record 6 of Set 1 | Punta Arenas
# Processing Record 7 of Set 1 | Mataura
# City not found. Skipping...
# Processing Record 9 of Set 1 | Laguna
# Processing Record 10 of Set 1 | Atuona
# Processing Record 11 of Set 1 | Northam
# Processing Record 12 of Set 1 | Bredasdorp
# Processing Record 13 of Set 1 | Barrow
# Processing Record 14 of Set 1 | Port Alfred
# Processing Record 15 of Set 1 | Ulladulla
# Processing Record 16 of Set 1 | Vaini
# Processing Record 17 of Set 1 | Sokoni
# Processing Record 18 of Set 1 | Albany
# Processing Record 19 of Set 1 | Katsuura
# Processing Record 20 of Set 1 | Lompoc
# Processing Record 21 of Set 1 | Mahébourg
# Processing Record 22 of Set 1 | Maceió
# Processing Record 23 of Set 1 | Camacha
# City not found. Skipping...
# Processing Record 25 of Set 1 | Boueni
# Processing Record 26 of Set 1 | Cherskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 1 | Hithadhoo
# Processing Record 30 of Set 1 | Cabo San Lucas
# Processing Record 31 of Set 1 | Rikitea
# Processing Record 32 of Set 1 | Pevek
# Processing Record 33 of Set 1 | Busselton
# Processing Record 34 of Set 1 | Dikson
# Processing Record 35 of Set 1 | Saskylakh
# Processing Record 36 of Set 1 | Ushuaia
# Processing Record 37 of Set 1 | Wau
# Processing Record 38 of Set 1 | Kismayo
# Processing Record 39 of Set 1 | Kindersley
# Processing Record 40 of Set 1 | Saint Anthony
# Processing Record 41 of Set 1 | Puerto Nariño
# Processing Record 42 of Set 1 | Salalah
# Processing Record 43 of Set 1 | San Patricio
# Processing Record 44 of Set 1 | Guerrero Negro
# Processing Record 45 of Set 1 | Galesong
# City not found. Skipping...
# Processing Record 47 of Set 1 | Safi
# Processing Record 48 of Set 1 | Kiryat Gat
# Processing Record 49 of Set 1 | Broken Hill
# Processing Record 50 of Set 1 | Peleduy
# Processing Record 1 of Set 2 | Kavieng
# Processing Record 2 of Set 2 | Umeå
# City not found. Skipping...
# Processing Record 4 of Set 2 | Lüderitz
# Processing Record 5 of Set 2 | Cosamaloapan
# City not found. Skipping...
# Processing Record 7 of Set 2 | Geraldton
# Processing Record 8 of Set 2 | Acacoyagua
# Processing Record 9 of Set 2 | Grindavik
# Processing Record 10 of Set 2 | Mossamedes
# Processing Record 11 of Set 2 | Hermanus
# Processing Record 12 of Set 2 | Baharly
# Processing Record 13 of Set 2 | East London
# Processing Record 14 of Set 2 | Cape Town
# Processing Record 15 of Set 2 | Esim
# Processing Record 16 of Set 2 | Thompson
# Processing Record 41 of Set 3 | Arraial do Cabo
# Processing Record 42 of Set 3 | Naze
# Processing Record 43 of Set 3 | Genoa
# Processing Record 44 of Set 3 | Paracuru
# Processing Record 45 of Set 3 | Upernavik
# City not found. Skipping...
# Processing Record 47 of Set 3 | Bilma
# Processing Record 48 of Set 3 | Bengkulu
# Processing Record 49 of Set 3 | Bara
# Processing Record 50 of Set 3 | Faanui
# Processing Record 1 of Set 4 | Plácido de Castro
# Processing Record 2 of Set 4 | Provideniya
# Processing Record 3 of Set 4 | Arman'
# Processing Record 4 of Set 4 | Avera
# Processing Record 5 of Set 4 | Mocuba
# Processing Record 6 of Set 4 | Ketchikan
# Processing Record 7 of Set 4 | Lucapa
# Processing Record 8 of Set 4 | Saldanha
# Processing Record 9 of Set 4 | Vardø
# Processing Record 10 of Set 4 | Tazovsky
# Processing Record 11 of Set 4 | Boyuibe
# Processing Record 12 of Set 4 | Lavrentiya
# Processing Record 13 of Set 4 | Kaeo
# Processing Record 14 of Set 4 | Novaya Igirma
# Processing Record 15 of Set 4 | Nuuk
# Processing Record 16 of Set 4 | Lebu
# Processing Record 17 of Set 4 | Hlatikulu
# Processing Record 18 of Set 4 | Asău
# Processing Record 19 of Set 4 | São José da Coroa Grande
# Processing Record 20 of Set 4 | Čačak
# Processing Record 21 of Set 4 | Fortuna
# Processing Record 22 of Set 4 | Vanavara
# Processing Record 23 of Set 4 | Yaring
# Processing Record 24 of Set 4 | Mount Gambier
# Processing Record 25 of Set 4 | Petropavlovskoye
# Processing Record 26 of Set 4 | Codrington
# Processing Record 27 of Set 4 | Yangi Marg`ilon
# Processing Record 28 of Set 4 | Iqaluit
# Processing Record 29 of Set 4 | Bambous Virieux
# Processing Record 30 of Set 4 | São Filipe
# Processing Record 31 of Set 4 | La Palma
# Processing Record 32 of Set 4 | Camalú
# Processing Record 33 of Set 4 | Dumai
# Processing Record 34 of Set 4 | Rio Grande
# Processing Record 35 of Set 4 | Hobart
# Processing Record 36 of Set 4 | Gamba
# Processing Record 37 of Set 4 | Lerwick
# Processing Record 38 of Set 4 | Hobyo
# Processing Record 39 of Set 4 | Garissa
# Processing Record 40 of Set 4 | Hong Kong
# Processing Record 41 of Set 4 | Vostok
# Processing Record 42 of Set 4 | Gaozhou
# City not found. Skipping...
# Processing Record 44 of Set 4 | Yakeshi
# Processing Record 45 of Set 4 | Tautira
# Processing Record 46 of Set 4 | Vágur
# Processing Record 47 of Set 4 | Bagdarin
# City not found. Skipping...
# Processing Record 49 of Set 4 | Khovd
# Processing Record 50 of Set 4 | Perelyub
# Processing Record 1 of Set 5 | Krasnosel'kup
# Processing Record 2 of Set 5 | San Quintín
# Processing Record 3 of Set 5 | Beya
# Processing Record 4 of Set 5 | Zemio
# Processing Record 5 of Set 5 | Padang
# Processing Record 6 of Set 5 | Souillac
# Processing Record 7 of Set 5 | Susa
# Processing Record 8 of Set 5 | Inírida
# City not found. Skipping...
# Processing Record 10 of Set 5 | Izumo
# Processing Record 11 of Set 5 | Hamilton
# Processing Record 12 of Set 5 | Podgornoye
# Processing Record 13 of Set 5 | Khatanga
# Processing Record 14 of Set 5 | Tevaitoa
# Processing Record 15 of Set 5 | Nhulunbuy
# Processing Record 16 of Set 5 | Mitsamiouli
# Processing Record 17 of Set 5 | Dukat
# Processing Record 18 of Set 5 | Dale
# Processing Record 19 of Set 5 | Santiago del Estero
# Processing Record 20 of Set 5 | Rognan
# Processing Record 21 of Set 5 | Victorville
# Processing Record 22 of Set 5 | Fes
# Processing Record 23 of Set 5 | Yellowknife
# Processing Record 24 of Set 5 | Kruisfontein
# Processing Record 25 of Set 5 | Coquimbo
# Processing Record 26 of Set 5 | Mar del Plata
# City not found. Skipping...
# Processing Record 28 of Set 5 | Calbuco
# City not found. Skipping...
# Processing Record 30 of Set 5 | Mackay
# Processing Record 31 of Set 5 | Severo-Kuril'sk
# Processing Record 32 of Set 5 | Tasiilaq
# City not found. Skipping...
# Processing Record 34 of Set 5 | Altay
# Processing Record 35 of Set 5 | Mount Isa
# Processing Record 36 of Set 5 | Nola
# Processing Record 37 of Set 5 | Santa Cruz de la Sierra
# Processing Record 38 of Set 5 | Doha
# Processing Record 39 of Set 5 | Maniitsoq
# Processing Record 40 of Set 5 | Ponta do Sol
# Processing Record 41 of Set 5 | Kutum
# Processing Record 42 of Set 5 | Bariloche
# Processing Record 43 of Set 5 | Visnes
# Processing Record 44 of Set 5 | Boshnyakovo
# Processing Record 45 of Set 5 | Sangīn
# City not found. Skipping...
# Processing Record 47 of Set 5 | Naples
# Processing Record 48 of Set 5 | Yuzhno-Kurilsk
# Processing Record 49 of Set 5 | Kahului
# Processing Record 50 of Set 5 | Aklavik
# Processing Record 1 of Set 6 | Eydhafushi
# Processing Record 2 of Set 6 | Goderich
# City not found. Skipping...
# Processing Record 4 of Set 6 | Waingapu
# Processing Record 5 of Set 6 | Nāthdwāra
# Processing Record 6 of Set 6 | Dingle
# Processing Record 7 of Set 6 | Clyde River
# Processing Record 8 of Set 6 | Visby
# Processing Record 9 of Set 6 | Mahon
# Processing Record 10 of Set 6 | Christchurch
# City not found. Skipping...
# Processing Record 12 of Set 6 | Pudozh
# Processing Record 13 of Set 6 | Almaznyy
# Processing Record 14 of Set 6 | Labuan
# Processing Record 15 of Set 6 | Chennai
# Processing Record 16 of Set 6 | Mackenzie
# Processing Record 17 of Set 6 | Gushikawa
# Processing Record 18 of Set 6 | Rawson
# Processing Record 19 of Set 6 | Acapulco de Juárez
# Processing Record 20 of Set 6 | Matara
# Processing Record 21 of Set 6 | Ghanzi
# Processing Record 22 of Set 6 | Aksu
# Processing Record 23 of Set 6 | Kindu
# Processing Record 24 of Set 6 | Shizunai-furukawachō
# Processing Record 25 of Set 6 | Paamiut
# City not found. Skipping...
# Processing Record 27 of Set 6 | Calvinia
# Processing Record 28 of Set 6 | Kieta
# Processing Record 29 of Set 6 | Manokwari
# Processing Record 30 of Set 6 | Concarneau
# Processing Record 31 of Set 6 | Portland
# City not found. Skipping...
# Processing Record 33 of Set 6 | Kundiawa
# Processing Record 34 of Set 6 | Hasaki
# Processing Record 35 of Set 6 | Araouane
# Processing Record 36 of Set 6 | Tommot
# Processing Record 37 of Set 6 | Kamenka
# Processing Record 38 of Set 6 | Marsh Harbour
# Processing Record 39 of Set 6 | Quelimane
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set

# City not found. Skipping...
# City not found. Skipping...
# Processing Record 2 of Set 10 | Inuvik
# Processing Record 3 of Set 10 | Banda Aceh
# Processing Record 4 of Set 10 | Praia
# Processing Record 5 of Set 10 | Port Lincoln
# Processing Record 6 of Set 10 | Dali
# Processing Record 7 of Set 10 | Rolla
# Processing Record 8 of Set 10 | Chara
# Processing Record 9 of Set 10 | Pirae
# City not found. Skipping...
# Processing Record 11 of Set 10 | Rosário do Sul
# Processing Record 12 of Set 10 | Pahrump
# Processing Record 13 of Set 10 | Halifax
# Processing Record 14 of Set 10 | Tuatapere
# Processing Record 15 of Set 10 | Uppsala County
# Processing Record 16 of Set 10 | Båtsfjord
# Processing Record 17 of Set 10 | Chambas
# Processing Record 18 of Set 10 | Hualmay
# Processing Record 19 of Set 10 | Lumphat
# Processing Record 20 of Set 10 | Chongwe
# Processing Record 21 of Set 10 | Hai’an
# Processing Record 22 of Set 10 | Talnakh
# Processing Record 23 of Set 10 | Manyana
# Processing Record 24 of Set 10 | Yulara
# Processing Record 25 of Set 10 | Bartica
# Processing Record 26 of Set 10 | Hirtshals
# Processing Record 27 of Set 10 | Pingliang
# Processing Record 28 of Set 10 | Karratha
# Processing Record 29 of Set 10 | Muisne
# Processing Record 30 of Set 10 | Mareeba
# Processing Record 31 of Set 10 | Sibolga
# Processing Record 32 of Set 10 | Samarai
# Processing Record 33 of Set 10 | Olinda
# Processing Record 34 of Set 10 | Pedini
# Processing Record 35 of Set 10 | Great Falls
# City not found. Skipping...
# Processing Record 37 of Set 10 | Copiapó
# Processing Record 38 of Set 10 | Cabedelo
# City not found. Skipping...
# Processing Record 40 of Set 10 | Kota Belud
# Processing Record 41 of Set 10 | Bud
# Processing Record 42 of Set 10 | Belen
# Processing Record 43 of Set 10 | Torbay
# Processing Record 44 of Set 10 | Sungai Penuh
# Processing Record 45 of Set 10 | Khandyga
# Processing Record 46 of Set 10 | Carutapera
# Processing Record 47 of Set 10 | Kalyazin
# Processing Record 48 of Set 10 | Urucará
# Processing Record 49 of Set 10 | Kantang
# City not found. Skipping...
# Processing Record 1 of Set 11 | Marabá
# Processing Record 2 of Set 11 | Tilichiki
# Processing Record 3 of Set 11 | Vanimo
# Processing Record 4 of Set 11 | Borogontsy
# Processing Record 5 of Set 11 | Richards Bay
# Processing Record 6 of Set 11 | Oranjemund
# City not found. Skipping...
# Processing Record 8 of Set 11 | Zhengjiatun
# Processing Record 9 of Set 11 | Torrington
# Processing Record 10 of Set 11 | Ust-Maya
# Processing Record 11 of Set 11 | Adrar
# Processing Record 12 of Set 11 | Bāfq
# Processing Record 13 of Set 11 | Olean
# Processing Record 14 of Set 11 | New Milford
# Processing Record 15 of Set 11 | The Valley
# Processing Record 16 of Set 11 | Nome
# Processing Record 17 of Set 11 | Port Elizabeth
# Processing Record 18 of Set 11 | Zakamensk
# Processing Record 19 of Set 11 | Keïta
# City not found. Skipping...
# Processing Record 21 of Set 11 | Moramanga
# Processing Record 22 of Set 11 | Moss Vale
# Processing Record 23 of Set 11 | Oktyabr'skiy
# Processing Record 24 of Set 11 | Miles City
# Processing Record 25 of Set 11 | Tupã
# Processing Record 26 of Set 11 | Gravelbourg
# City not found. Skipping...
# Processing Record 28 of Set 11 | Sangar
# Processing Record 29 of Set 11 | Tura
# Processing Record 30 of Set 11 | Aykhal
# Processing Record 31 of Set 11 | Marsá Maţrūḩ
# Processing Record 32 of Set 11 | Xiongzhou
# Processing Record 33 of Set 11 | Bikin
# Processing Record 34 of Set 11 | Ahipara
# Processing Record 35 of Set 11 | Sioux Lookout
# Processing Record 36 of Set 11 | Andahuaylas
# Processing Record 37 of Set 11 | Nkhata Bay
# Processing Record 38 of Set 11 | Atasū
# Processing Record 39 of Set 11 | Oranjestad
# Processing Record 40 of Set 11 | Nerchinskiy Zavod
# Processing Record 41 of Set 11 | Port Moresby
# City not found. Skipping...
# Processing Record 43 of Set 11 | Bāgli
# Processing Record 44 of Set 11 | Kumul
# Processing Record 45 of Set 11 | Kortkeros
# Processing Record 46 of Set 11 | Faya
# Processing Record 47 of Set 11 | Xining
# Processing Record 48 of Set 11 | Kaputa
# Processing Record 49 of Set 11 | Saiha
# Processing Record 50 of Set 11 | Cartagena
# Processing Record 1 of Set 12 | Puerto del Rosario
# Processing Record 2 of Set 12 | Panama City
# Processing Record 3 of Set 12 | Yar-Sale
# Processing Record 4 of Set 12 | Sobolevo
# Processing Record 5 of Set 12 | Viranşehir
# Processing Record 6 of Set 12 | Berlevåg
# Processing Record 7 of Set 12 | Nabire
# Processing Record 8 of Set 12 | Kawalu
# Processing Record 9 of Set 12 | Plettenberg Bay
# Processing Record 10 of Set 12 | Mahād
# Processing Record 11 of Set 12 | Amahai
# Processing Record 12 of Set 12 | Nelson Bay
# Processing Record 13 of Set 12 | Khanbari
# Processing Record 14 of Set 12 | Tigil'
# Processing Record 15 of Set 12 | Sampit
# Processing Record 16 of Set 12 | Solnechnyy
# Processing Record 17 of Set 12 | Muros
# Processing Record 18 of Set 12 | Antofagasta
# Processing Record 19 of Set 12 | Sharlyk
# Processing Record 20 of Set 12 | Pontal do Paraná
# Processing Record 21 of Set 12 | Posse
# Processing Record 22 of Set 12 | Paraíso
# Processing Record 23 of Set 12 | Beringovskiy
# Processing Record 24 of Set 12 | Talcahuano
# Processing Record 25 of Set 12 | Honiara
# Processing Record 26 of Set 12 | Rapid Valley
# Processing Record 27 of Set 12 | Rāvar
# Processing Record 28 of Set 12 | Yatou
# Processing Record 29 of Set 12 | Havelock
# Processing Record 30 of Set 12 | Victor Harbor
# Processing Record 31 of Set 12 | Verkhnevilyuysk
# Processing Record 32 of Set 12 | Pareora
# Processing Record 33 of Set 12 | Harper
# Processing Record 34 of Set 12 | Qiongshan
# City not found. Skipping...
# Processing Record 36 of Set 12 | Nishihara
# Processing Record 37 of Set 12 | Rio das Ostras
# Processing Record 38 of Set 12 | Cayenne
# Processing Record 39 of Set 12 | Tefé
# Processing Record 40 of Set 12 | Flinders
# Processing Record 41 of Set 12 | Kyaikkami
# Processing Record 42 of Set 12 | Carlsbad
# Processing Record 43 of Set 12 | Boguchany
# Processing Record 44 of Set 12 | Belmonte
# Processing Record 45 of Set 12 | Ust-Kuyga
# Processing Record 46 of Set 12 | Xiongyue
# Processing Record 47 of Set 12 | Los Llanos de Aridane
# Processing Record 48 of Set 12 | Kununurra
# Processing Record 49 of Set 12 | Dawei
# Processing Record 50 of Set 12 | Tiarei
# Processing Record 1 of Set 13 | Moanda
# Processing Record 2 of Set 13 | Guadalupe y Calvo
# Processing Record 3 of Set 13 | Avanigadda
# Processing Record 4 of Set 13 | Filingué
# Processing Record 5 of Set 13 | Homer
# Processing Record 6 of Set 13 | Chatrā
# Processing Record 7 of Set 13 | Nānākuli
# Processing Record 8 of Set 13 | Half Moon Bay
# Processing Record 9 of Set 13 | Batagay
# Processing Record 10 of Set 13 | Ponta Delgada
# Processing Record 11 of Set 13 | Sorong
# Processing Record 12 of Set 13 | Ouadda
# Processing Record 13 of Set 13 | Aquin
# Processing Record 14 of Set 13 | Ulaangom
# Processing Record 15 of Set 13 | Haimen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a panda data frame using data retrieved
weather_dict = pd.DataFrame({ 
                "City" : city_id,
                "Cloudiness" : cloudiness,
                "Country" : country,
                "Date" : date,
                "Humidity" : humidity,
                "Lat" : lat,
                "Lng" : lng,
                "Max Temp" : max_temp,
                "Wind Speed" : wind_speed
})

# %%
weather_dict.count()
# Out:
# City          560
# Cloudiness    560
# Country       560
# Date          560
# Humidity      560
# Lat           560
# Lng           560
# Max Temp      560
# Wind Speed    560
# dtype: int64

# %%
weather_dict
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Beni Mazar           0      EG  1598743080        57  28.50   30.80
# 1           Hilo          40      US  1598742799        52  19.73 -155.09
# 2    George Town          40      MY  1598742904        94   5.41  100.34
# 3         Avarua          14      CK  1598743051        73 -21.21 -159.78
# 4      Zonguldak           0      TR  1598743081        38  41.25   31.83
# ..           ...         ...     ...         ...       ...    ...     ...
# 555       Sorong         100      ID  1598743198        85  -0.88  131.25
# 556       Ouadda         100      CF  1598743199        96   8.08   22.40
# 557        Aquin          47      HT  1598743199        80  18.28  -73.40
# 558     Ulaangom          91      MN  1598743199        64  49.98   92.07
# 559       Haimen          20      CN  1598743199        94  23.19  116.61
#
#      Max Temp  Wind Speed
# 0       80.37       15.28
# 1       87.80       10.29
# 2       77.00        3.36
# 3       77.00       17.22
# 4       68.59        4.56
# ..        ...         ...
# 555     76.95        7.96
# 556     68.00        4.81
# 557     82.65        2.57
# 558     51.35        1.95
# 559     80.60        2.24
#
# [560 rows x 9 columns]

# %%
weather_dict.to_csv("output_data.csv", index = False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_dict["Lat"], weather_dict["Max Temp"], facecolor = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)
plt.savefig("../images/Latitude vs Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_dict["Lat"], weather_dict["Humidity"], facecolor = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Humidity")
plt.xlabel("Laitude")
plt.ylabel("Humidity (%)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)
plt.savefig("../images/Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_dict["Lat"], weather_dict["Cloudiness"], facecolor = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Cloudiness (01/17/20)")
plt.xlabel("Laitude")
plt.ylabel("Cloudiness (%)")
plt.ylim(-5,105)
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)
plt.savefig("../images/Latitude vs Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_dict["Lat"], weather_dict["Wind Speed"], facecolor = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (mph) (01/17/20)")
plt.xlabel("Laitude")
plt.ylabel("Wind Speed (%)")
plt.ylim(-2,50)
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)
plt.savefig("../images/Latitude vs Wind Speed.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linear_regression(x, y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regression = x * slope + intercept
    line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x, regression, "r-")
    print(f"The R² value is: {round(st.pearsonr(x, y)[0],2)}")
    return regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_dict.loc[weather_dict["Lat"] >= 0]
southern_hemisphere = weather_dict.loc[weather_dict["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
regression = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (°F)")
plt.savefig("../images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The R² value is: -0.79

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
regression = linear_regression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (°F)")
plt.savefig("../images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The R² value is: 0.77

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
regression = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("../images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The R² value is: -0.1

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
regression = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("../images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The R² value is: 0.14

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
regression = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The R² value is: 0.03

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
regression = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("../images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The R² value is: 0.03

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
regression = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("../images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The R² value is: 0.07

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
regression = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("../images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The R² value is: -0.24
